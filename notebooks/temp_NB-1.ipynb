# %%
import subprocess
pkgs = ["faiss-cpu", "sentence-transformers", "pdfplumber",
        "pypdf", "langchain", "langchain-community",
        "langchain-huggingface", "transformers",
        "accelerate", "fpdf2", "tqdm", "gradio", "plotly"]
for pkg in pkgs:
    r = subprocess.run(["pip", "install", pkg, "-q", "--no-cache-dir"],
                       capture_output=True, text=True)
    print(f"{'✅' if r.returncode == 0 else '❌'} {pkg}")
# Out:
# ✅ faiss-cpu
# ✅ sentence-transformers
# ✅ pdfplumber
# ✅ pypdf
# ✅ langchain
# ✅ langchain-community
# ✅ langchain-huggingface
# ✅ transformers
# ✅ accelerate
# ✅ fpdf2
# ✅ tqdm
# ✅ gradio
# ✅ plotly

# %%
import sys
sys.path.insert(0, "/workspace/shared/audit_validator")
exec(open("/workspace/shared/audit_validator/src/app.py").read())
# Out:
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://e8d820364deb0a823a.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e8d820364deb0a823a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 🤖 AuditAgent initializing...
# Index loaded: 22 vectors
# ✅ AuditAgent ready.
#
# ...
# 📄 Starting audit: /tmp/uploaded_doc.pdf
# ...
# [Document parse] 0.173s
#    Words: 671 | Chunks: 2
#    (Limited to 6 chunks for speed)
#
# Validating chunk 1/2...
# Loading embedding model on: cuda
# Embedding model loaded: BAAI/bge-small-en-v1.5
# Loading Qwen/Qwen2.5-7B-Instruct ...
# `torch_dtype` is deprecated! Use `dtype` instead!
# ...

# %%
from datetime import datetime
import json

day6_log = {
    "day":          6,
    "date":         datetime.now().isoformat(),
    "improvements": [
        "Visual gauge chart for overall compliance score",
        "Horizontal bar chart for per-framework scores",
        "Donut pie chart for status breakdown",
        "Demo enterprise contract PDF generated",
        "UI layout polished with dashboard section",
        "plotly integrated into Gradio"
    ],
    "demo_pdf": "demo_enterprise_contract.pdf",
    "charts":   ["gauge", "framework_bar", "status_pie"],
    "status":   "complete"
}

with open("/workspace/shared/audit_validator/logs/day6_summary.json", "w") as f:
    json.dump(day6_log, f, indent=2)

print(json.dumps(day6_log, indent=2))
print("\n✅ Day 6 complete!")
# Out:
# {
#   "day": 6,
#   "date": "2026-06-10T06:57:37.707531",
#   "improvements": [
#     "Visual gauge chart for overall compliance score",
#     "Horizontal bar chart for per-framework scores",
#     "Donut pie chart for status breakdown",
#     "Demo enterprise contract PDF generated",
#     "UI layout polished with dashboard section",
#     "plotly integrated into Gradio"
#   ],
#   "demo_pdf": "demo_enterprise_contract.pdf",
#   "charts": [
#     "gauge",
#     "framework_bar",
#     "status_pie"
#   ],
#   "status": "complete"
# }
#
# ✅ Day 6 complete!
